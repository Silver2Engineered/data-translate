# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
df = pd.read_csv('./covid-data.csv')

# %%
df['submission_date'] = pd.to_datetime(df['submission_date'])
df = df.sort_values(['state', 'submission_date'])
df
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 4532       2020-01-22    AK          0         NaN         NaN         0
# 357        2020-01-23    AK          0         NaN         NaN         0
# 2704       2020-01-24    AK          0         NaN         NaN         0
# 37706      2020-01-25    AK          0         NaN         NaN         0
# 5696       2020-01-26    AK          0         NaN         NaN         0
# ...               ...   ...        ...         ...         ...       ...
# 33357      2022-01-21    WY     135369    106504.0     28865.0      1874
# 30931      2022-01-22    WY     135369    106504.0     28865.0         0
# 19540      2022-01-23    WY     135369    106504.0     28865.0         0
# 34296      2022-01-24    WY     137873    108554.0     29319.0      2504
# 30877      2022-01-25    WY     139461    109726.0     29735.0      1588
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 4532         NaN          0         NaN         NaN          0         NaN
# 357          NaN          0         NaN         NaN          0         NaN
# 2704         NaN          0         NaN         NaN          0         NaN
# 37706        NaN          0         NaN         NaN          0         NaN
# 5696         NaN          0         NaN         NaN          0         NaN
# ...          ...        ...         ...         ...        ...         ...
# 33357      355.0       1601      1601.0         0.0          0         0.0
# 30931        0.0       1601      1601.0         0.0          0         0.0
# 19540        0.0       1601      1601.0         0.0          0         0.0
# 34296      454.0       1601      1601.0         0.0          0         0.0
# 30877      416.0       1625      1625.0         0.0         24         0.0
#
#                    created_at consent_cases consent_deaths
# 4532   03/26/2020 04:22:39 PM           NaN            NaN
# 357    03/26/2020 04:22:39 PM           NaN            NaN
# 2704   03/26/2020 04:22:39 PM           NaN            NaN
# 37706  03/26/2020 04:22:39 PM           NaN            NaN
# 5696   03/26/2020 04:22:39 PM           NaN            NaN
# ...                       ...           ...            ...
# 33357  01/22/2022 02:22:36 PM         Agree          Agree
# 30931  01/24/2022 02:28:34 PM         Agree          Agree
# 19540  01/24/2022 03:59:16 PM         Agree          Agree
# 34296  01/25/2022 02:33:43 PM         Agree          Agree
# 30877  01/26/2022 03:12:02 PM         Agree          Agree
#
# [44100 rows x 15 columns]

# %%
state = 'CA'

df_ca = df[df['state'] == state]

df_ca['tot_cases_diff'] = df_ca['tot_cases'].diff()
df_ca
# Out:
# C:\Users\sfitc\AppData\Local\Temp\ipykernel_71148\3690026505.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ca['tot_cases_diff'] = df_ca['tot_cases'].diff()
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 25559      2020-01-22    CA          0         0.0         0.0         0
# 12887      2020-01-23    CA          0         0.0         0.0         0
# 17546      2020-01-24    CA          0         0.0         0.0         0
# 15811      2020-01-25    CA          0         0.0         0.0         0
# 23711      2020-01-26    CA          0         0.0         0.0         0
# ...               ...   ...        ...         ...         ...       ...
# 15277      2022-01-21    CA    7570538   7123571.0    446967.0    125861
# 12157      2022-01-22    CA    7570538   7123571.0    446967.0         0
# 22672      2022-01-23    CA    7570538   7123571.0    446967.0         0
# 13594      2022-01-24    CA    7866610   7419643.0    446967.0    296072
# 9524       2022-01-25    CA    7929436   7482469.0    446967.0     62826
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 25559        0.0          0         NaN         NaN          0         0.0
# 12887        0.0          0         NaN         NaN          0         0.0
# 17546        0.0          0         NaN         NaN          0         0.0
# 15811        0.0          0         NaN         NaN          0         0.0
# 23711        0.0          0         NaN         NaN          0         0.0
# ...          ...        ...         ...         ...        ...         ...
# 15277        0.0      77722         NaN         NaN        201         0.0
# 12157        0.0      77722         NaN         NaN          0         0.0
# 22672        0.0      77722         NaN         NaN          0         0.0
# 13594        0.0      78101         NaN         NaN        379         0.0
# 9524         0.0      78118         NaN         NaN         17         0.0
#
#                    created_at consent_cases consent_deaths  tot_cases_diff
# 25559  01/24/2020 12:00:00 AM         Agree      Not agree             NaN
# 12887  01/25/2020 12:00:00 AM         Agree      Not agree             0.0
# 17546  01/26/2020 12:00:00 AM         Agree      Not agree             0.0
# 15811  01/27/2020 12:00:00 AM         Agree      Not agree             0.0
# 23711  01/28/2020 12:00:00 AM         Agree      Not agree             0.0
# ...                       ...           ...            ...             ...
# 15277  01/22/2022 02:22:36 PM         Agree      Not agree        125861.0
# 12157  01/24/2022 02:28:34 PM         Agree      Not agree             0.0
# 22672  01/24/2022 03:59:16 PM         Agree      Not agree             0.0
# 13594  01/25/2022 02:33:43 PM         Agree      Not agree        296072.0
# 9524   01/26/2022 03:12:02 PM         Agree      Not agree         62826.0
#
# [735 rows x 16 columns]

# %%
df_ca['tot_cases_diff'].mean()
# Out:
# 10803.046321525886

# %%
df_ca['new_case_diff'] = df_ca.iloc['new_case'].diff()
print(df_ca['new_case_diff'].mean())
df_ca
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\sfitc\Documents\Northwestern\Comp_Sci_338\data-translate\server\experiments.ipynb Cell 6' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sfitc/Documents/Northwestern/Comp_Sci_338/data-translate/server/experiments.ipynb#ch0000005?line=0'>1</a> df_ca['new_case_diff'] = df_ca.iloc['new_case'].diff()
#       <a href='vscode-notebook-cell:/c%3A/Users/sfitc/Documents/Northwestern/Comp_Sci_338/data-translate/server/experiments.ipynb#ch0000005?line=1'>2</a> print(df_ca['new_case_diff'].mean())
#       <a href='vscode-notebook-cell:/c%3A/Users/sfitc/Documents/Northwestern/Comp_Sci_338/data-translate/server/experiments.ipynb#ch0000005?line=2'>3</a> df_ca
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///~/miniconda3/lib/site-packages/pandas/core/indexing.py?line=963'>964</a> axis = self.axis or 0
#     <a href='file:///~/miniconda3/lib/site-packages/pandas/core/indexing.py?line=965'>966</a> maybe_callable = com.apply_if_callable(key, self.obj)
# --> <a href='file:///~/miniconda3/lib/site-packages/pandas/core/indexing.py?line=966'>967</a> return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1517, in _iLocIndexer._getitem_axis(self, key, axis)
#    <a href='file:///~/miniconda3/lib/site-packages/pandas/core/indexing.py?line=1514'>1515</a> key = item_from_zerodim(key)
#    <a href='file:///~/miniconda3/lib/site-packages/pandas/core/indexing.py?line=1515'>1516</a> if not is_integer(key):
# -> <a href='file:///~/miniconda3/lib/site-packages/pandas/core/indexing.py?line=1516'>1517</a>     raise TypeError("Cannot index by location index with a non-integer key")
#    <a href='file:///~/miniconda3/lib/site-packages/pandas/core/indexing.py?line=1518'>1519</a> # validate the location
#    <a href='file:///~/miniconda3/lib/site-packages/pandas/core/indexing.py?line=1519'>1520</a> self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
mean_diff = df_ca['new_case_diff'].mean()

sentence = 'The average new weekly cases in {0} was {1} from {2} to {3}.'.format(
    state, 
    round(mean_diff, 2), 
    df_ca['submission_date'].iloc[0].date(), 
    df_ca['submission_date'].iloc[-1].date())

print(sentence)
# Out:
# The average new weekly cases in CA was 85.59 from 2020-01-22 to 2022-01-25.

# %%
percent_change_dict = {}
# percent_change_df = df.filter(['state'], axis=1)
for state in data:
    cases_last_week = whatever
    cases_this_week = whatever
    percent_change = (cases_this_week - cases_last_week) / cases_last_week
    percent_change_dict[state] = percent_change
df = dataframe_from_records(percent_change_dict)
#once dict is populated, we can find the closest state to our current state
df_sort = df.iloc[(df['num']-our_state).abs().argsort()[:2]]
df_sort.index.tolist()

# %%
df['submission_date'] = pd.to_datetime(df['submission_date']) #done in app.py
df.sort_values('submission_date')

col = 'new_case'

new_df = pd.DataFrame(columns=('state', 'prev_week', 'cur_week', 'percent_change'))

for state in df['state'].unique():
    entry = []
    entry.append(state) # state
    entry.append(df[df['state'] == state].iloc[-14:-8][col].mean()) # prev_week
    entry.append(df[df['state'] == state].iloc[-7:-1][col].mean()) # cur_week
    if entry[1] == 0 and entry[2] == 0:
        entry.append(0) # 0 cases no change
    elif entry[1] == 0:
        entry.append('') # 0 last week
    else:
        entry.append((entry[2] - entry[1]) / entry[1] * 100) # percent_change
    new_df.loc[len(new_df.index)] = entry
    
state = 'WA'
state_percent_change = new_df[new_df['state'] == state]['percent_change'].iloc[0]
df_other_states = new_df[new_df['state'] != state]

selection = (df_other_states['percent_change'] - state_percent_change).abs().argsort()

df_other_states.iloc[selection]
# Out:
#    state      prev_week       cur_week  percent_change
# 59    WY     619.000000    1220.000000       97.092084
# 30    MT     963.833333    1851.000000       92.045651
# 36    NM    2940.666667    5404.000000       83.767853
# 42    OR    4531.500000    8142.500000       79.686638
# 19    KS    6942.333333   12400.333333       78.619100
# 16    ID    1598.666667    2774.500000       73.550876
# 25    MI   10110.000000   17493.000000       73.026706
# 0     AK    1617.166667    3641.166667      125.157168
# 52    UT    5723.000000    9623.833333       68.160638
# 13    GU     360.333333     599.166667       66.281221
# 49    SD    1322.166667    2190.166667       65.649817
# 37    NV    3418.333333    5641.000000       65.021941
# 26    MN    5625.333333   13426.000000      138.670301
# 34    NH    1627.666667    2426.500000       49.078435
# 29    MS    4310.000000    6168.166667       43.112916
# 32    ND    1591.833333    2133.666667       34.038321
# 55    VT     438.666667    1171.833333      167.135258
# 22    MA   10112.500000   12623.666667       24.832303
# 27    MO    9798.166667   11646.333333       18.862372
# 20    KY    9978.333333   11724.666667       17.501253
# 24    ME     810.000000     922.000000       13.827160
# 12    GA   16390.166667   18653.666667       13.810110
# 21    LA    7780.333333    8439.500000        8.472216
# 58    WV    4668.500000    4921.333333        5.415730
# 4     AZ   19379.666667   20268.000000        4.583842
# 1     AL   11143.166667   11598.833333        4.089203
# 50    TN   17003.666667   17543.500000        3.174805
# 41    OK   11304.500000   11646.166667        3.022395
# 18    IN   13982.333333   14304.666667        2.305290
# 47   RMI       0.000000       0.000000        0.000000
# 11   FSM       0.000000       0.000000        0.000000
# 2     AR    9158.500000    8982.000000       -1.927171
# 14    HI    4043.166667    3961.666667       -2.015747
# 5     CA  118200.333333  113504.000000       -3.973198
# 15    IA    5135.000000    4834.000000       -5.861733
# 33    NE    4222.666667    3853.500000       -8.742501
# 17    IL   29020.000000   25813.000000      -11.050999
# 6     CO   11851.166667   10222.000000      -13.746888
# 51    TX   66061.166667   54794.500000      -17.054901
# 53    VA   15358.000000   12019.166667      -21.740027
# 31    NC   32572.000000   25197.166667      -22.641635
# 28    MP      45.500000      33.000000      -27.472527
# 54    VI     134.500000      96.166667      -28.500620
# 10    FL   45941.333333   31222.500000      -32.038324
# 8     DC     714.166667     473.833333      -33.652275
# 7     CT    6924.833333    4341.833333      -37.300537
# 43    PA   26321.500000   15651.000000      -40.539103
# 46    RI    4532.833333    2602.833333      -42.578226
# 40    OH   29460.666667   16192.833333      -45.035754
# 9     DE    3220.333333    1748.500000      -45.704378
# 38    NY   24085.166667   12887.500000      -46.491963
# 35    NJ   18573.000000    9639.000000      -48.102084
# 23    MD    9315.500000    4815.000000      -48.311953
# 57    WI   24419.666667   11679.000000      -52.173794
# 39   NYC   21094.333333   10081.000000      -52.209914
# 44    PR    7540.833333    3514.666667      -53.391535
# 48    SC   17496.166667    6158.500000      -64.800861
# 3     AS       1.166667       0.000000     -100.000000
# 45    PW      20.166667     101.333333      402.479339
